# %%
#3x3 grid
#3 in a row ([x][x+1]), col ([x+1][x]), dia ([x+1][x+-1]= WIN CON
#Check win con every loop
#Fill boxes with either "X" or "O"
#If grid is filled with win con not met = DRAW
#Import math library so I can use isnan function later
import math

# %%
#Set as 1 and 4 so that no matter which case 
#player_X = 1
#player_O = 4

#whoWon = False

# %%
#Win Condition - Rows

#Checks the sum of each array to determine whether a win condion is met for X or O
# def rowWinCon():
#     for row in grid:
#         print(row)
#         if sum(row) == 3 * player_X:
#             print("X's have won")
#             whoWon = player_X
#             isgameOver = True

#         elif sum(row) == 3 * player_O:
#             print("O's have won")
#             whoWon = player_O
#             isgameOver = True

#         else:
#             print("Draw")
#             whowon = False

# %%
#Win Condition - Columns

# def colWinCon():
#     for col in range(3):
#         total = 0
#         print("Col: ", col)
#         for row in range(3):
#             print("Row: ", row)
#             total += grid[row][col]
#             print("Total: ", total)
#         #Check if the win con is met    
#         if total == 3 * player_X:
#             print("X's have won")
#             whoWon = player_X
#             isgameOver = True
            
#         elif total == 3 * player_O:
#             print("O's have won")
#             whoWon = player_O
#             isgameOver = True
            
#         else:
#             print("Draw")
#             whoWon = False

# %%
# define column sum
# define diag sum

# board[00]

# %%
### check rows sum is 12 or 3
### check cols sum  sum(test)
### check diag sum


### then check for draw

### else next turn

# %%
#Win Condion - Diagionals

# Either ([0][0],[1][1],[2][2]) or ([2][2],[1][1],[0][0])
#diagTlBrTotal is  from Top Left to Bottom Right
#diagTrBLTotal is from Top Right to Bottom Left
# def diagWinCon():
#     diagTlBrTotal = 0
#     diagTrBlTotal = 0
#     for col in range(3):
#         #print("Col: ", col)
#         for row in range(3):
#             #print("Row: ", row)
#             if row == col:
#                 diagTlBrTotal += testForDiag[row][col]
#                 diagTrBlTotal += testForDiag[row][2-col]

#             #elif row == 2-col:
#                 #print(row, col)
#                 #inverseTotal += testForDiag[row][3-col]
#             print("Total: ", diagTlBrTotal)
#             print("Inverse: ",diagTrBlTotal)
#     print("Final Total: ", diagTlBrTotal)
#     print("Final Inverse Total: ", diagTrBlTotal)

#     #Conditions for game state
#     if diagTlBrTotal == 3 * player_X or diagTrBlTotal == 3 * player_X:
#         print("X's have won")
#         whoWon = player_X
#         isgameOver = True

#     elif diagTlBrTotal == 3 * player_X or diagTrBlTotal == 3 * player_O:
#         print("O's have won")
#         whoWon = player_O
#         isgameOver = True

#     else:
#         print("Draw")
#         whoWon = False

# %%
#Draw condition

# def drawCon():
#     for row in grid:
#         for value in row:
#             print(value)
#             if math.isnan(value) == True:
#                 isGameOver = False
#                 break
#             else:
#                 isGameOver = True
    
#     print(isGameOver)

# %%
# def playerMove(playerTurn, ticTacToeGrid):
#     while True:
#         #Asks user for input to find out what row they want to interact with
#         makeMoveRow = int(input("What row do+ you want to put your symbol in?: 1, 2, 3 "))

#         #Asks user for input to find out what column they want to interact with
#         makeMoveCol = int(input("What column do you want to put the symbol in?: 1, 2, 3 "))

#         #Postion the user whants to replace the value of in the grid
#         valueToReplace = ticTacToeGrid[makeMoveRow-1][makeMoveCol-1] 
#         print(valueToReplace)

#         #Action to replace value user want to either "X" or "O"
#         if math.isnan(valueToReplace) == True: 
#             ticTacToeGrid[makeMoveRow-1][makeMoveCol-1] = playerTurn
#             print(ticTacToeGrid)
#             break
#         else:
#             print("This spot has already been taken")

# %%
# def playTicTacToe():
#     #Declaring variables
#     player_X = 1
#     player_O = 4
#     whoWon = False
#     isgameOver = False
#     #Create the list for player turns 
#     playerTurns = [player_X, player_O, player_X, player_O, player_X, player_O, player_X, player_O, player_X]
#     #Runs the function to make a 3x3 grid of NaN values
#     grid = createNewGrid()
#     #Create a while loop to run the game until the "isgameOver" is true
#     while isgameOver == False:
#         for player in playerTurns:
#             print(grid)
#             #print(type(playerTurns[player]))

#             playerMove(playerTurns[player], grid)

#             rowWinCon()
#             colWinCon()
#             diagWinCon()
            
#             if whoWon == player_X:
#                 isgameOver = True
#             elif whoWon == player_O:
#                 isgameOver = True
#             else:
#                 drawCon()

# #print("test")            
# #playTicTacToe()

# %%
# print("test")

# %%
class TicTacToe:
    def __init__(self):
        self.player_X = 1
        self.player_O = 4
        self.whoWon = False
        self.isGameOver = False
        self.playerTurns = [self.player_X, self.player_O, self.player_X, self.player_O, self.player_X, self.player_O, self.player_X, self.player_O, self.player_X]
        self.grid = [[float("nan") for i in range(3)] for i in range(3)]
    
    #Win Condition - Rows
    #Checks the sum of each array to determine whether a win condion is met for X or O
    def displayGrid(self):
        for x in self.grid:
            print(x)
            
    def rowWinCon(self):
        for row in self.grid:
            
            
            if sum(row) == 3 * self.player_X:
                print("X's have won")
                self.whoWon = self.player_X
                self.isgameOver = True
                break

            elif sum(row) == 3 * self.player_O:
                print("O's have won")
                self.whoWon = self.player_O
                self.isgameOver = True
                break

            else:
#                 print("Draw")
                self.whowon = False
        
    def colWinCon(self):
        for col in range(3):
            total = 0
#             print("Col: ", col)
            
            for row in range(3):
#                 print("Row: ", row)
                total += self.grid[row][col]
#                 print("Total: ", total)
                
            #Check if the win con is met    
            if total == 3 * self.player_X:
                print("X's have won")
                self.whoWon = self.player_X
                self.isgameOver = True
                break

            elif total == 3 * self.player_O:
                print("O's have won")
                self.whoWon = self.player_O
                self.isgameOver = True
                break

            else:
#                 print(total)
#                 print("Draw")
                self.whoWon = False

    #Win Condion - Diagionals
    # Either ([0][0],[1][1],[2][2]) or ([2][2],[1][1],[0][0])
    #diagTlBrTotal is  from Top Left to Bottom Right
    #diagTrBLTotal is from Top Right to Bottom Left
    def diagWinCon(self):
        diagTlBrTotal = 0
        diagTrBlTotal = 0
        for col in range(3):
            #print("Col: ", col)
            for row in range(3):
                #print("Row: ", row)
                if row == col:
                    diagTlBrTotal += self.grid[row][col]
                    diagTrBlTotal += self.grid[row][2-col]

                #elif row == 2-col:
                    #print(row, col)
                    #inverseTotal += testForDiag[row][3-col]
#                 print("Total: ", diagTlBrTotal)
#                 print("Inverse: ",diagTrBlTotal)
#         print("Final Total: ", diagTlBrTotal)
#         print("Final Inverse Total: ", diagTrBlTotal)

        #Conditions for game state
        if diagTlBrTotal == 3 * self.player_X or diagTrBlTotal == 3 * self.player_X:
            print("X's have won")
            self.whoWon = self.player_X
            self.isgameOver = True

        elif diagTlBrTotal == 3 * self.player_X or diagTrBlTotal == 3 * self.player_O:
            print("O's have won")
            self.whoWon = self.player_O
            self.isgameOver = True

        else:
#             print("Draw")
            self.whoWon = False
            
    def drawCon(self):
        #Checks in each row if there is a value that nan if so that means the game is not over
        for row in self.grid:
            for value in row:
                if math.isnan(value) == True:
                    self.isGameOver = False
                    break
                else:
                    self.isGameOver = True
                    

        print(self.isGameOver)


    def playerMove(self, playerTurnIndex):
        while True:
            #Asks user for input to find out what row they want to interact with
            makeMoveRow = int(input("What row do you want to put your symbol in?: 1, 2, 3 "))

            #Asks user for input to find out what column they want to interact with
            makeMoveCol = int(input("What column do you want to put the symbol in?: 1, 2, 3 "))

            #Postion the user whants to replace the value of in the grid
            valueToReplace = self.grid[makeMoveRow-1][makeMoveCol-1] 
#             1print(valueToReplace)

            #Action to replace value user want to either "X" or "O"
            if math.isnan(valueToReplace) == True: 
                #Trying to update the position in the grid with the current value being iterated over
                #Currently updates the grid position with the entire list of "playerTurns"
                self.grid[makeMoveRow-1][makeMoveCol-1] = self.playerTurns[playerTurnIndex]
                self.displayGrid()
                break
            else:
                print("This spot has already been taken")
    
    def playTicTacToe(self):
        #Create a while loop to run the game until the "isgameOver" is true
#         print(hasattr(self, "whoWon"))
        
        while self.isGameOver == False:
            #Enumerate gives you the index and the values for each item in an array
            for index, player in enumerate(self.playerTurns):
                self.displayGrid()
                #print(type(playerTurns[player]))

                self.playerMove(index)

                self.rowWinCon()
                self.colWinCon()
                self.diagWinCon()

                if self.whoWon == self.player_X:
                    self.isgameOver = True
                    break
                elif self.whoWon == self.player_O:
                    self.isgameOver = True
                    break
                else:
                    self.drawCon()
            
                    

game1 = TicTacToe()
game1.playTicTacToe()
# Out:
# [nan, nan, nan]
# [nan, nan, nan]
# [nan, nan, nan]
# What row do you want to put your symbol in?: 1, 2, 3 1
# What column do you want to put the symbol in?: 1, 2, 3 1
# [1, nan, nan]
# [nan, nan, nan]
# [nan, nan, nan]
# False
# [1, nan, nan]
# [nan, nan, nan]
# [nan, nan, nan]
# What row do you want to put your symbol in?: 1, 2, 3 1
# What column do you want to put the symbol in?: 1, 2, 3 2
# [1, 4, nan]
# [nan, nan, nan]
# [nan, nan, nan]
# False
# [1, 4, nan]
# [nan, nan, nan]
# [nan, nan, nan]
# What row do you want to put your symbol in?: 1, 2, 3 2
# What column do you want to put the symbol in?: 1, 2, 3 2
# [1, 4, nan]
# [nan, 1, nan]
# [nan, nan, nan]
# False
# [1, 4, nan]
# [nan, 1, nan]
# [nan, nan, nan]
# What row do you want to put your symbol in?: 1, 2, 3 1
# What column do you want to put the symbol in?: 1, 2, 3 3
# [1, 4, 4]
# [nan, 1, nan]
# [nan, nan, nan]
# False
# [1, 4, 4]
# [nan, 1, nan]
# [nan, nan, nan]
# What row do you want to put your symbol in?: 1, 2, 3 3
# What column do you want to put the symbol in?: 1, 2, 3 3
# [1, 4, 4]
# [nan, 1, nan]
# [nan, nan, 1]
# X's have won
# [1, 4, 4]
# [nan, 1, nan]
# [nan, nan, 1]
